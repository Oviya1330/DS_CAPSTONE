# %%
#!pip install pytesseract pillow
# Out:
# Collecting pytesseract
#   Using cached pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pillow in o:\ds_capestone\prelims\.venv\lib\site-packages (11.0.0)
# Requirement already satisfied: packaging>=21.3 in o:\ds_capestone\prelims\.venv\lib\site-packages (from pytesseract) (25.0)
# Using cached pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pytesseract
from PIL import Image

# Path to your image file
image_path = "test1.png"

# If on Windows, set tesseract path manually:
# pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# Open the image
img = Image.open(image_path)

# Extract text
extracted_text = pytesseract.image_to_string(img)

print("📝 Extracted Text:")
print(extracted_text)
# Out:
# 📝 Extracted Text:
# Your api.data.gov API key Inbox x
#
# = B
# noreply@api.data.gov via mail128-135.atl41.mandrillapp.com 6:15 PM (49 minutes ago) « hd
# to info |~
# Hi Kin,
#
# Your API key for is:
#
# QYC8QbKSVr6sSl1nJOJSZbx8eUVazwed5s5FRPw4KC
#
# You can start using this key to make Web service requests. Simply pass your key in the URL when making a Web request.
# Here's an example:
#
# https://api.data.gov/nrel/alt-fuel-stations/vl/nearest.json?api key=QYC8QbKSVr6sS1nJOJSZbx8e
# Uazwed5s5FRPw4KC& location=Denver+CO
#
# What Next?
#
# e Explore our available Web services.
# e Need more help? Contact us.
#
# For additional support, please contact us. When contacting us, please tell us what API you're accessing and provide the following account details so we can
# quickly find you:

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Collecting numpy<2.3.0,>=2 (from opencv-python)
#   Downloading numpy-2.2.6-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/60.8 kB 667.8 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 816.2 kB/s eta 0:00:00
# Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/39.0 MB 7.3 MB/s eta 0:00:06
#    - -------------------------------------- 1.8/39.0 MB 18.7 MB/s eta 0:00:02
#    -- ------------------------------------- 2.5/39.0 MB 22.8 MB/s eta 0:00:02
#    -- ------------------------------------- 2.6/39.0 MB 16.8 MB/s eta 0:00:03
#    --- ------------------------------------ 3.1/39.0 MB 13.0 MB/s eta 0:00:03
#    --- ------------------------------------ 3.8/39.0 MB 13.4 MB/s eta 0:00:03
#    ---- ----------------------------------- 4.8/39.0 MB 14.6 MB/s eta 0:00:03
#    ------ --------------------------------- 6.2/39.0 MB 16.6 MB/s eta 0:00:02
#    ------- -------------------------------- 7.6/39.0 MB 18.0 MB/s eta 0:00:02
#    --------- ------------------------------ 8.9/39.0 MB 18.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 10.3/39.0 MB 21.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 11.7/39.0 MB 21.1 MB/s eta 0:00:02
#    ------------- -------------------------- 13.1/39.0 MB 26.2 MB/s eta 0:00:01
#    -------------- ------------------------- 14.4/39.0 MB 28.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 15.8/39.0 MB 29.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 16.3/39.0 MB 28.5 MB/s eta 0:00:01
#    ------------------ --------------------- 18.2/39.0 MB 29.7 MB/s eta 0:00:01
#    -------------------- ------------------- 19.6/39.0 MB 29.7 MB/s eta 0:00:01
#    --------------------- ------------------ 21.0/39.0 MB 29.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 22.4/39.0 MB 29.8 MB/s eta 0:00:01
#    ------------------------ --------------- 23.7/39.0 MB 28.5 MB/s eta 0:00:01
#    ------------------------- -------------- 25.2/39.0 MB 29.7 MB/s eta 0:00:01
#    --------------------------- ------------ 26.5/39.0 MB 29.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 27.9/39.0 MB 31.2 MB/s eta 0:00:01
#    ------------------------------ --------- 29.3/39.0 MB 29.7 MB/s eta 0:00:01
#    ------------------------------- -------- 30.6/39.0 MB 29.7 MB/s eta 0:00:01
#    -------------------------------- ------- 31.8/39.0 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.4/39.0 MB 29.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.7/39.0 MB 29.8 MB/s eta 0:00:01
#    ------------------------------------- -- 36.1/39.0 MB 29.7 MB/s eta 0:00:01
#    -------------------------------------- - 37.5/39.0 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------  38.9/39.0 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------  39.0/39.0 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------- 39.0/39.0 MB 24.2 MB/s eta 0:00:00
# Downloading numpy-2.2.6-cp312-cp312-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --- ------------------------------------ 1.2/12.6 MB 38.4 MB/s eta 0:00:01
#    -------- ------------------------------- 2.6/12.6 MB 32.8 MB/s eta 0:00:01
#    ------------ --------------------------- 4.0/12.6 MB 31.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.2/12.6 MB 30.3 MB/s eta 0:00:01
#    --------------------- ------------------ 6.7/12.6 MB 30.6 MB/s eta 0:00:01
#    ------------------------- -------------- 8.2/12.6 MB 30.7 MB/s eta 0:00:01
#    ------------------------------ --------- 9.5/12.6 MB 30.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.9/12.6 MB 29.7 MB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.6 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 26.2 MB/s eta 0:00:00
# Installing collected packages: numpy, opencv-python
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.3
#     Uninstalling numpy-2.3.3:
#       Successfully uninstalled numpy-2.3.3
# Successfully installed numpy-2.2.6 opencv-python-4.12.0.88
#   WARNING: Failed to remove contents in a temporary directory 'O:\ds_capestone\Prelims\.venv\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'O:\ds_capestone\Prelims\.venv\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pytesseract
from pytesseract import Output
import cv2
# Load image
image_path = "test1.png"
img = cv2.imread(image_path)

# Get OCR data (text + bounding boxes)
ocr_data = pytesseract.image_to_data(img, output_type=Output.DICT)

# %%
for i in range(len(ocr_data['text'])):
    word = ocr_data['text'][i]
    if word.strip() != "":
        print(f"{i}: {word} (x={ocr_data['left'][i]}, y={ocr_data['top'][i]}, w={ocr_data['width'][i]}, h={ocr_data['height'][i]})")
# Out:
# 4: Your (x=22, y=24, w=75, h=26)
# 5: api.data.gov (x=107, y=24, w=190, h=33)
# 6: API (x=308, y=24, w=54, h=26)
# 7: key (x=377, y=24, w=52, h=33)
# 8: Inbox (x=561, y=32, w=52, h=16)
# 9: x (x=641, y=36, w=11, h=12)
# 13: = (x=1760, y=30, w=70, h=24)
# 14: B (x=1808, y=26, w=26, h=39)
# 16: noreply@api.data.gov (x=124, y=117, w=265, h=24)
# 17: via (x=406, y=117, w=33, h=23)
# 18: mail128-135.atl41.mandrillapp.com (x=447, y=117, w=396, h=24)
# 19: 6:15 (x=1336, y=117, w=49, h=19)
# 20: PM (x=1394, y=117, w=35, h=19)
# 21: (49 (x=1439, y=117, w=35, h=24)
# 22: minutes (x=1484, y=117, w=87, h=19)
# 23: ago) (x=1580, y=117, w=49, h=24)
# 24: « (x=1725, y=117, w=25, h=21)
# 25: hd (x=1801, y=122, w=12, h=7)
# 27: to (x=112, y=164, w=20, h=18)
# 28: info (x=142, y=163, w=39, h=19)
# 29: |~ (x=199, y=166, w=10, h=6)
# 31: Hi (x=114, y=248, w=23, h=36)
# 32: Kin, (x=136, y=252, w=62, h=26)
# 36: Your (x=112, y=316, w=64, h=22)
# 37: API (x=184, y=316, w=46, h=22)
# 38: key (x=242, y=316, w=45, h=28)
# 39: for (x=296, y=316, w=35, h=22)
# 40: is: (x=341, y=316, w=26, h=22)
# 44: QYC8QbKSVr6sSl1nJOJSZbx8eUazwed5s5FRPw4KC (x=123, y=390, w=862, h=30)
# 48: You (x=112, y=528, w=52, h=22)
# 49: can (x=175, y=534, w=45, h=16)
# 50: start (x=231, y=529, w=58, h=21)
# 51: using (x=299, y=528, w=68, h=28)
# 52: this (x=378, y=528, w=45, h=22)
# 53: key (x=434, y=528, w=45, h=28)
# 54: to (x=488, y=529, w=23, h=21)
# 55: make (x=522, y=528, w=71, h=22)
# 56: Web (x=603, y=528, w=60, h=22)
# 57: service (x=673, y=528, w=93, h=22)
# 58: requests. (x=777, y=529, w=120, h=27)
# 59: Simply (x=909, y=528, w=88, h=28)
# 60: pass (x=1008, y=534, w=60, h=22)
# 61: your (x=1078, y=534, w=58, h=22)
# 62: key (x=1146, y=528, w=45, h=28)
# 63: in (x=1201, y=528, w=20, h=22)
# 64: the (x=1231, y=528, w=40, h=22)
# 65: URL (x=1283, y=528, w=57, h=22)
# 66: when (x=1349, y=528, w=70, h=22)
# 67: making (x=1431, y=528, w=93, h=28)
# 68: a (x=1535, y=534, w=15, h=16)
# 69: Web (x=1560, y=528, w=60, h=22)
# 70: request. (x=1631, y=529, w=105, h=27)
# 72: Here's (x=114, y=562, w=83, h=22)
# 73: an (x=207, y=568, w=31, h=16)
# 74: example: (x=249, y=562, w=118, h=28)
# 78: https://api.data.gov/nrel/alt-fuel-stations/vl/nearest.json?api (x=123, y=630, w=1132, h=28)
# 79: key=QYC8QbKSVr6sS1nJOJSZbx8e (x=1275, y=632, w=502, h=26)
# 81: Uazwed5s5FRPw4KC& (x=122, y=666, w=302, h=20)
# 82: location=Denver+CO (x=436, y=665, w=315, h=21)
# 94: What (x=112, y=736, w=84, h=26)
# 95: Next? (x=209, y=735, w=90, h=27)
# 99: e (x=190, y=816, w=10, h=10)
# 100: Explore (x=224, y=808, w=99, h=28)
# 101: our (x=333, y=814, w=43, h=16)
# 102: available (x=385, y=808, w=116, h=22)
# 103: Web (x=511, y=808, w=60, h=22)
# 104: services. (x=581, y=808, w=116, h=22)
# 106: e (x=190, y=850, w=10, h=10)
# 107: Need (x=224, y=842, w=68, h=22)
# 108: more (x=304, y=848, w=65, h=16)
# 109: help? (x=381, y=842, w=70, h=28)
# 110: Contact (x=462, y=842, w=102, h=22)
# 111: us. (x=574, y=848, w=36, h=16)
# 119: For (x=122, y=942, w=34, h=18)
# 120: additional (x=164, y=942, w=100, h=18)
# 121: support, (x=273, y=943, w=84, h=22)
# 122: please (x=367, y=942, w=68, h=23)
# 123: contact (x=443, y=943, w=77, h=17)
# 124: us. (x=528, y=947, w=29, h=13)
# 125: When (x=566, y=942, w=61, h=18)
# 126: contacting (x=636, y=942, w=107, h=23)
# 127: us, (x=752, y=947, w=29, h=16)
# 128: please (x=791, y=942, w=69, h=23)
# 129: tell (x=867, y=942, w=29, h=18)
# 130: us (x=906, y=947, w=23, h=13)
# 131: what (x=937, y=942, w=50, h=18)
# 132: API (x=994, y=942, w=37, h=18)
# 133: you're (x=1040, y=942, w=63, h=23)
# 134: accessing (x=1111, y=942, w=105, h=23)
# 135: and (x=1225, y=942, w=37, h=18)
# 136: provide (x=1272, y=942, w=77, h=23)
# 137: the (x=1356, y=942, w=33, h=18)
# 138: following (x=1396, y=942, w=92, h=23)
# 139: account (x=1497, y=943, w=83, h=17)
# 140: details (x=1588, y=942, w=68, h=18)
# 141: so (x=1663, y=947, w=24, h=13)
# 142: we (x=1695, y=947, w=30, h=13)
# 143: can (x=1733, y=947, w=36, h=13)
# 145: quickly (x=121, y=970, w=72, h=23)
# 146: find (x=200, y=970, w=37, h=18)
# 147: you: (x=246, y=975, w=43, h=18)
